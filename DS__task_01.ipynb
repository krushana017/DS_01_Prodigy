# %% [markdown]
# # __IMPORT LIBRARIES__

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # IMPORT DATA

# %%
df=pd.read_csv(r"C:\Users\91932\Downloads\DS_1.csv")
#DATAFRAME
df
# Out:
#             Series Name        Series Code           Country Name  \
# 0     Population, total        SP.POP.TOTL            Afghanistan
# 1     Population, total        SP.POP.TOTL                Albania
# 2     Population, total        SP.POP.TOTL                Algeria
# 3     Population, total        SP.POP.TOTL         American Samoa
# 4     Population, total        SP.POP.TOTL                Andorra
# ..                  ...                ...                    ...
# 428  Population, female  SP.POP.TOTL.FE.IN                Vietnam
# 429  Population, female  SP.POP.TOTL.FE.IN  Virgin Islands (U.S.)
# 430  Population, female  SP.POP.TOTL.FE.IN     West Bank and Gaza
# 431  Population, female  SP.POP.TOTL.FE.IN            Yemen, Rep.
# 432  Population, female  SP.POP.TOTL.FE.IN                 Zambia
#
#     Country Code      2022      2021      2020      2019      2018      2017  \
# 0            AFG  41128771  40099462  38972230  37769499  36686784  35643418
# ...

# %%
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code      2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824
#
#        2021      2020      2019      2018      2017  ...      2010      2009  \
# 0  40099462  38972230  37769499  36686784  35643418  ...  28189672  27385307
# 1   2811666   2837849   2854191   2866376   2873457  ...   2913021   2927519
# 2  44177969  43451666  42705368  41927007  41136546  ...  35856344  35196037
# 3     45035     46189     47321     48424     49463  ...     54849     55366
# 4     79034     77700     76343     75013     73837  ...     71519     73852
#
# ...

# %%
df.tail()
# Out:
#             Series Name        Series Code           Country Name  \
# 428  Population, female  SP.POP.TOTL.FE.IN                Vietnam
# 429  Population, female  SP.POP.TOTL.FE.IN  Virgin Islands (U.S.)
# 430  Population, female  SP.POP.TOTL.FE.IN     West Bank and Gaza
# 431  Population, female  SP.POP.TOTL.FE.IN            Yemen, Rep.
# 432  Population, female  SP.POP.TOTL.FE.IN                 Zambia
#
#     Country Code      2022      2021      2020      2019      2018      2017  \
# 428          VNM  49685569  49331842  48922527  48488283  48058062  47620370
# 429          VIR     56275     56360     56425     56473     56512     56522
# 430          PSE   2527169   2467389   2408409   2350358   2293162   2236936
# 431          YEM  16673411  16313210  15963067  15593113  15211556  14831892
# 432          ZMB  10140033   9864121   9589102   9314079   9041177   8772120
#
#      ...      2010      2009      2008      2007      2006      2005  \
# ...

# %% [markdown]
# # DATA OVERVIEW

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433 entries, 0 to 432
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   433 non-null    object
#  1   Series Code   433 non-null    object
#  2   Country Name  433 non-null    object
#  3   Country Code  433 non-null    object
#  4   2022          433 non-null    int64
#  5   2021          433 non-null    int64
#  6   2020          433 non-null    int64
#  7   2019          433 non-null    int64
#  8   2018          433 non-null    int64
#  9   2017          433 non-null    int64
#  10  2016          433 non-null    int64
#  11  2015          433 non-null    int64
#  12  2014          433 non-null    int64
#  13  2013          433 non-null    int64
#  14  2012          433 non-null    int64
#  15  2011          433 non-null    int64
#  16  2010          433 non-null    int64
#  17  2009          433 non-null    int64
# ...

# %%
df.describe()
# Out:
#                2022          2021          2020          2019          2018  \
# count  4.330000e+02  4.330000e+02  4.330000e+02  4.330000e+02  4.330000e+02
# mean   2.739527e+07  2.717442e+07  2.693910e+07  2.666645e+07  2.638593e+07
# std    1.113792e+08  1.109330e+08  1.103890e+08  1.096760e+08  1.088914e+08
# min    5.513000e+03  5.449000e+03  5.367000e+03  5.301000e+03  5.252000e+03
# 25%    6.161590e+05  6.129850e+05  6.070650e+05  6.003010e+05  5.937150e+05
# 50%    4.944055e+06  4.843921e+06  4.741717e+06  4.640105e+06  4.569087e+06
# 75%    1.772332e+07  1.744611e+07  1.691099e+07  1.660403e+07  1.634695e+07
# max    1.417173e+09  1.412360e+09  1.411100e+09  1.407745e+09  1.402760e+09
#
#                2017          2016          2015          2014          2013  \
# count  4.330000e+02  4.330000e+02  4.330000e+02  4.330000e+02  4.330000e+02
# mean   2.609669e+07  2.579908e+07  2.549923e+07  2.519852e+07  2.489451e+07
# ...

# %%
df.isnull().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %% [markdown]
# # DATA CLEANING

# %% [markdown]
# ## __DROP UNUSEFUL COLUMNS__

# %%
print(df.shape)
# Out:
# (433, 26)

# %%
print(df.columns)
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %%
df=df.drop(['Country Code', 'Series Name','Series Code'], axis=1)
df
# Out:
#               Country Name      2022      2021      2020      2019      2018  \
# 0              Afghanistan  41128771  40099462  38972230  37769499  36686784
# 1                  Albania   2775634   2811666   2837849   2854191   2866376
# 2                  Algeria  44903225  44177969  43451666  42705368  41927007
# 3           American Samoa     44273     45035     46189     47321     48424
# 4                  Andorra     79824     79034     77700     76343     75013
# ..                     ...       ...       ...       ...       ...       ...
# 428                Vietnam  49685569  49331842  48922527  48488283  48058062
# 429  Virgin Islands (U.S.)     56275     56360     56425     56473     56512
# 430     West Bank and Gaza   2527169   2467389   2408409   2350358   2293162
# 431            Yemen, Rep.  16673411  16313210  15963067  15593113  15211556
# 432                 Zambia  10140033   9864121   9589102   9314079   9041177
#
# ...

# %%
 years = ['2022', '2021', '2020', '2019', '2018', '2017', '2016','2015', '2014', '2013', '2012', '2011', '2010',
 '2009', '2008', '2007','2006', '2005', '2004', '2003', '2002', '2001']

# %%
sort_year=df.sort_values(by='2001').head(15)
sort_year_t=sort_year.set_index('Country Name').T
for i,j in sort_year_t.iterrows():
    fig = plt.figure(figsize = (10, 5))
    sns.barplot(x=j.index,y=j.values,color ='pink', width = 0.4)
    plt.xticks(rotation=90)
    plt.xlabel("Country Name")
    
    #plt.ylabel(f"values on {i}")
    plt.title(f"values on {i}")
    plt.show()

# %%
plt.hist(population, bins=20, color='skyblue', edgecolor='black')
plt.show()
